# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] =(15,3)
plt.rcParams['font.family'] = 'sans-serif'

# %%
weather_2012_final = pd.read_csv('/Users/bibhu/Documents/DataAnalysis/data/weather_2012.csv', index_col='Date/Time')

# %%
weather_2012_final
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# ...                       ...                 ...          ...
# 2012-12-31 19:00:00       0.1                -2.7           81
# 2012-12-31 20:00:00       0.2                -2.4           83
# 2012-12-31 21:00:00      -0.5                -1.5           93
# 2012-12-31 22:00:00      -0.2                -1.8           89
# 2012-12-31 23:00:00       0.0                -2.1           86
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# ...

# %%
weather_2012_final['Temp (C)'].plot()
# Out:
# <AxesSubplot:xlabel='Date/Time'>

# %%
weather_mar2012 = pd.read_csv('/Users/bibhu/Documents/DataAnalysis/data/weather_2012.csv')

# %%
weather_mar2012
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %%
weather_mar2012 = weather_mar2012.dropna(axis =1, how ='any')
weather_mar2012[:5]
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
weather_mar2012 = weather_mar2012.drop(['Year', 'Month', 'Day', 'Time', 'Data Quality'], axis=1)
weather_mar2012[:5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 weather_mar2012 = weather_mar2012.drop(['Year', 'Month', 'Day', 'Time', 'Data Quality'], axis=1)
#       2 weather_mar2012[:5]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
temperatures = weather_mar2012[[u'Temp (C)']].copy()
print(temperatures.head)
temperatures.loc[:,'Hour'] = weather_mar2012.index.hour
temperatures.groupby('Hour').aggregate(np.median).plot()
# Out:
# <bound method NDFrame.head of       Temp (C)
# 0         -1.8
# 1         -1.8
# 2         -1.8
# 3         -1.5
# 4         -1.5
# ...        ...
# 8779       0.1
# 8780       0.2
# 8781      -0.5
# 8782      -0.2
# 8783       0.0
#
# [8784 rows x 1 columns]>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 temperatures = weather_mar2012[[u'Temp (C)']].copy()
#       2 print(temperatures.head)
# ----> 3 temperatures.loc[:,'Hour'] = weather_mar2012.index.hour
#       4 temperatures.groupby('Hour').aggregate(np.median).plot()
#
# AttributeError: 'RangeIndex' object has no attribute 'hour'

# %%
#to add two dataframes
weather_2012 = pd.concat(data_by_month)
weather_2012
weather_2012.to_csv('../data/weather_2012.csv')
