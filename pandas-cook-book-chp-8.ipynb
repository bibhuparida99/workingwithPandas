# %%
import pandas as pd

# %%
# Read it, and remove the last row
popcon = pd.read_csv('/Users/bibhu/Documents/DataAnalysis/data/popularity-contest', sep=' ', )[:-1]
popcon.columns = ['atime', 'ctime', 'package-name', 'mru-program', 'tag']

# %%
popcon['atime'] = popcon['atime'].astype(int)

# %%
popcon[:5]
# Out:
#         atime       ctime  package-name  \
# 0  1387295797  1367633260     perl-base
# 1  1387295796  1354370480         login
# 2  1387295743  1354341275    libtalloc2
# 3  1387295743  1387224204  libwbclient0
# 4  1387295742  1354341253   libselinux1
#
#                                     mru-program             tag
# 0                                 /usr/bin/perl             NaN
# 1                                       /bin/su             NaN
# 2  /usr/lib/x86_64-linux-gnu/libtalloc.so.2.0.7             NaN
# 3    /usr/lib/x86_64-linux-gnu/libwbclient.so.0  <RECENT-CTIME>
# 4         /lib/x86_64-linux-gnu/libselinux.so.1             NaN

# %%
popcon['atime'] = pd.to_datetime(popcon['atime'], unit='s')
popcon[:4]
# Out:
#                 atime       ctime  package-name  \
# 0 2013-12-17 15:56:37  1367633260     perl-base
# 1 2013-12-17 15:56:36  1354370480         login
# 2 2013-12-17 15:55:43  1354341275    libtalloc2
# 3 2013-12-17 15:55:43  1387224204  libwbclient0
#
#                                     mru-program             tag
# 0                                 /usr/bin/perl             NaN
# 1                                       /bin/su             NaN
# 2  /usr/lib/x86_64-linux-gnu/libtalloc.so.2.0.7             NaN
# 3    /usr/lib/x86_64-linux-gnu/libwbclient.so.0  <RECENT-CTIME>

# %%
popcon['ctime'] = pd.to_datetime(popcon['ctime'],unit ='s')
popcon[:9]
# Out:
#                 atime               ctime         package-name  \
# 0 2013-12-17 15:56:37 2013-05-04 02:07:40            perl-base
# 1 2013-12-17 15:56:36 2012-12-01 14:01:20                login
# 2 2013-12-17 15:55:43 2012-12-01 05:54:35           libtalloc2
# 3 2013-12-17 15:55:43 2013-12-16 20:03:24         libwbclient0
# 4 2013-12-17 15:55:42 2012-12-01 05:54:13          libselinux1
# 5 2013-12-17 15:55:42 2012-12-01 05:54:35           libstdc++6
# 6 2013-12-17 15:55:40 2013-12-16 20:03:22       libpam-winbind
# 7 2013-12-17 15:55:40 2012-12-01 05:54:13       libpam-modules
# 8 2013-12-17 15:55:40 2012-12-01 05:54:13  libpam-ck-connector
#
#                                      mru-program             tag
# 0                                  /usr/bin/perl             NaN
# 1                                        /bin/su             NaN
# 2   /usr/lib/x86_64-linux-gnu/libtalloc.so.2.0.7             NaN
# 3     /usr/lib/x86_64-linux-gnu/libwbclient.so.0  <RECENT-CTIME>
# 4          /lib/x86_64-linux-gnu/libselinux.so.1             NaN
# 5  /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.16             NaN
# 6  /lib/x86_64-linux-gnu/security/pam_winbind.so  <RECENT-CTIME>
# 7     /lib/x86_64-linux-gnu/security/pam_unix.so             NaN
# 8              /lib/security/pam_ck_connector.so             NaN

# %%
popcon = popcon[popcon['atime'] > '1970-01-01']
