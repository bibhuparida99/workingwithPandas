# %%
# The usual preamble
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

# %%
requests  = pd.read_csv('/Users/bibhu/Documents/DataAnalysis/data/311-service-requests.csv', dtype='unicode')
requests[:5]
# Out:
#   Unique Key            Created Date             Closed Date Agency                              Agency Name           Complaint Type                    Descriptor        Location Type Incident Zip  Incident Address      Street Name   Cross Street 1                    Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type      City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board    Borough X Coordinate (State Plane) Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name            Latitude           Longitude                                  Location
# ...

# %%
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...

# %%
na_values = ['NO CLUE', 'N/A', '0']
requests  = pd.read_csv('/Users/bibhu/Documents/DataAnalysis/data/311-service-requests.csv',na_values = na_values, dtype={'Incident Zip': str})

# %%
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...

# %%
rows_with_dashes = requests['Incident Zip'].str.contains('-').fillna(False)

# %%
rows_with_dashes
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 111064    False
# 111065    False
# 111066    False
# 111067    False
# 111068    False
# Name: Incident Zip, Length: 111069, dtype: bool

# %%
requests[rows_with_dashes]
# Out:
#        Unique Key            Created Date             Closed Date Agency                     Agency Name      Complaint Type         Descriptor Location Type Incident Zip        Incident Address         Street Name Cross Street 1 Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type        City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board      Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  Latitude  Longitude Location
# ...

# %%
long_zip_codes = requests['Incident Zip'].str.len() >5
requests['Incident Zip'][long_zip_codes].unique()
# Out:
# array(['77092-2016', '55164-0737', '000000', '11549-3650', '29616-0759',
#        '35209-3114'], dtype=object)

# %%
long_zipcodes[:6]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Incident Zip, dtype: bool

# %%
requests['Incident Zip'][long_zip_codes].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 requests['Incident Zip'][long_zip_codes].unique()
#
# NameError: name 'long_zip_codes' is not defined

# %%
unique_zips = requests['Incident Zip'].unique()
unique_zips
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...

# %%
unique_zips_sort = unique_zips.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 unique_zips_sort = unique_zips.sort()
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
zips = requests['Incident Zip']
# Let's say the zips starting with '0' and '1' are okay, for now. (this isn't actually true -- 13221 is in Syracuse, and why?)
is_close = zips.str.startswith('0') | zips.str.startswith('1')
# There are a bunch of NaNs, but we're not interested in them right now, so we'll say they're False
is_far = ~(is_close) & zips.notnull()

# %%
requests['City'].str.upper().value_counts()
# Out:
# BROOKLYN          31662
# NEW YORK          22664
# BRONX             18438
# STATEN ISLAND      4766
# JAMAICA            2246
#                   ...
# BELLEVILLE            1
# WOODBURY              1
# BOHIEMA               1
# CENTRAL ISLIP         1
# NEWARK AIRPORT        1
# Name: City, Length: 100, dtype: int64

# %%
def fix_zip_codes(zips):
    # Truncate everything to length 5 
    zips = zips.str.slice(0, 5)
    
    # Set 00000 zip codes to nan
    zero_zips = zips == '00000'
    zips[zero_zips] = np.nan
    
    return zips

# %%
requests['Incident Zip'] = fix_zip_codes(requests['Incident Zip'])

# %%
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...
